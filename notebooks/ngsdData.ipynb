# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_excel("ng sd data.xlsx",sheet_name="daily sd",skiprows=[0,1])

# %%
data.head()
# Out:
#    weekday       date  production (source 1)  production (source 2)  \
# 0        4 2015-01-01              71.924128                 71.849
# 1        5 2015-01-02              71.910024                 71.843
# 2        6 2015-01-03              71.206279                 71.251
# 3        7 2015-01-04              71.086729                 71.076
# 4        1 2015-01-05              71.088634                 70.997
#
#    Canadian import  Export to Mexico  LNG net export  \
# 0         5.680812          1.968364       -0.068681
# 1         6.229438          2.026650       -0.068681
# 2         6.565548          2.172027       -0.025681
# 3         6.409509          2.176923       -0.029681
# 4         6.947736          2.287802       -0.100681
#
#    total Burn in power generation  Net weather normalized power burns  \
# 0                          23.392                            1.672910
# 1                          22.996                            5.257342
# 2                          21.600                            5.480145
# 3                          23.293                            5.356240
# 4                          25.192                            3.210589
#
#    nuclear gas burn  hydro gas burn  wind gas burn  Net normalized burn
# 0         -0.191260        0.537368       0.026138             2.045155
# 1         -0.113233        0.576331      -0.953068             4.767371
# 2         -0.019832        0.659123      -0.093736             6.025700
# 3         -0.059219        0.553217       1.068460             6.918698
# 4          0.035148       -0.074008       1.280076             4.451805

# %%
data["date"] = data["date"].astype(str)  + " 06:20:00"

# %%
data.rename ({"date":"datetime"},axis=1,inplace=True)

# %%
data.head()
# Out:
#    weekday             datetime  production (source 1)  production (source 2)  \
# 0        4  2015-01-01 06:20:00              71.924128                 71.849
# 1        5  2015-01-02 06:20:00              71.910024                 71.843
# 2        6  2015-01-03 06:20:00              71.206279                 71.251
# 3        7  2015-01-04 06:20:00              71.086729                 71.076
# 4        1  2015-01-05 06:20:00              71.088634                 70.997
#
#    Canadian import  Export to Mexico  LNG net export  \
# 0         5.680812          1.968364       -0.068681
# 1         6.229438          2.026650       -0.068681
# 2         6.565548          2.172027       -0.025681
# 3         6.409509          2.176923       -0.029681
# 4         6.947736          2.287802       -0.100681
#
#    total Burn in power generation  Net weather normalized power burns  \
# 0                          23.392                            1.672910
# 1                          22.996                            5.257342
# 2                          21.600                            5.480145
# 3                          23.293                            5.356240
# 4                          25.192                            3.210589
#
#    nuclear gas burn  hydro gas burn  wind gas burn  Net normalized burn
# 0         -0.191260        0.537368       0.026138             2.045155
# 1         -0.113233        0.576331      -0.953068             4.767371
# 2         -0.019832        0.659123      -0.093736             6.025700
# 3         -0.059219        0.553217       1.068460             6.918698
# 4          0.035148       -0.074008       1.280076             4.451805

# %%
data.to_csv("dailySd.csv",index=False,float_format='%.2f')

# %%
data = pd.read_excel("ng sd data.xlsx",sheet_name="weekly storage survey actual",skiprows=[0])

# %%
data.head()
# Out:
#    year    release   end.date  eia  consensus medium Wed 3:30pm cst  \
# 0  2015 2015-03-05 2015-02-26 -229                           -225.0
# 1  2015 2015-03-12 2015-03-05 -198                           -194.5
# 2  2015 2015-03-19 2015-03-12  -43                            -50.1
# 3  2015 2015-03-26 2015-03-19   11                              9.5
# 4  2015 2015-04-02 2015-03-26  -18                            -11.2
#
#    allstar (a top group) Wed 3:30pm cst  ice swap market Thursday 9am cst  \
# 0                                -227.0                               NaN
# 1                                -197.0                               NaN
# 2                                 -51.5                               NaN
# 3                                   8.3                               NaN
# 4                                 -12.7                               NaN
#
#    Implied weather adjusted balance vs 5-year average  \
# 0                                           5.295428
# 1                                           1.945124
# 2                                           1.785065
# 3                                           1.422265
# 4                                          -0.490715
#
#    Implied weather adjusted balance vs previous year
# 0                                           5.667715
# 1                                          -0.284875
# 2                                           1.732580
# 3                                           1.100688
# 4                                          -0.883496

# %%
data["release"] = data["release"].astype(str)  + " 09:30:00"

# %%
data.head()
# Out:
#    year              release   end.date  eia  consensus medium Wed 3:30pm cst  \
# 0  2015  2015-03-05 09:30:00 2015-02-26 -229                           -225.0
# 1  2015  2015-03-12 09:30:00 2015-03-05 -198                           -194.5
# 2  2015  2015-03-19 09:30:00 2015-03-12  -43                            -50.1
# 3  2015  2015-03-26 09:30:00 2015-03-19   11                              9.5
# 4  2015  2015-04-02 09:30:00 2015-03-26  -18                            -11.2
#
#    allstar (a top group) Wed 3:30pm cst  ice swap market Thursday 9am cst  \
# 0                                -227.0                               NaN
# 1                                -197.0                               NaN
# 2                                 -51.5                               NaN
# 3                                   8.3                               NaN
# 4                                 -12.7                               NaN
#
#    Implied weather adjusted balance vs 5-year average  \
# 0                                           5.295428
# 1                                           1.945124
# 2                                           1.785065
# 3                                           1.422265
# 4                                          -0.490715
#
#    Implied weather adjusted balance vs previous year
# 0                                           5.667715
# 1                                          -0.284875
# 2                                           1.732580
# 3                                           1.100688
# 4                                          -0.883496

# %%
data.rename ({"release":"datetime"},axis=1,inplace=True)

# %%
data.to_csv("weeklyStorageSurvey.csv",index=False,float_format='%.2f')
